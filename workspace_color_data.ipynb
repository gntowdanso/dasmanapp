# %%
# We will use this to generate color palettes or simple transformations if needed.
# Letshego Colors
# Blue: #0055A5
# Yellow: #FFDA00
# White: #FFFFFF

def to_tailwind(hex_color):
    pass # No need for logic here, just noting the colors.
